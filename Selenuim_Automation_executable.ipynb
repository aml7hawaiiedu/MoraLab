# %% [markdown]
# <a href="https://colab.research.google.com/github/aml7hawaiiedu/MoraLab/blob/main/Selenuim_Automation_executable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install selenium
# !pip install selenium

# %%
# !apt-get update

# %%
# Install chromium browser in your notebook
# !apt-get install -y chromium-browser

# %%
# Instal chromium chrome driver
# !apt install chromium-chromedriver

# %%
# Test the code
from selenium import webdriver

# %%
# Add dependencies
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

# %%
# Search to ensure chromium-browser - it will be used as an executable for our webdriver
# !ls /usr/bin/chromium-browser
# Out:
# /usr/bin/chromium-browser

# %%
# Add options to ensure any errors go away
options = webdriver.ChromeOptions()
options.add_argument('--no-sandbox')
options.add_argument('--headless')
options.add_argument('--disable-gpu')
options.add_argument('--disable-dev-shm-usage')
options.binary_location = '/usr/bin/chromium-browser'  # Set the path to Chromium binary

# %%
#  Install and access WebDriver (create new instance of Chrome)
driver = webdriver.Chrome(options=options)

# %% [markdown]
# # Exaples

# %%
# Test selenium - this is an example
# driver.get('https://quotes.toscrape.com/')

# %%
# # Example script: Loop through every quote
# /html/body/div/div[2]/div[1]/div[1] -- the copied xpath for the first one
# for element in driver.find_elements(By.XPATH, '//div[@class="quote"]'):
#   print('___\n___',element.text)

# %%
# # Open a file for writing
# with open('example.txt', 'w') as f:
#     # Extract and write search results to the file (you might need to modify the XPath)
#     for element in driver.find_elements(By.XPATH, '//div[@class="quote"]'):
#         f.write(element.text + '\n')

# %% [markdown]
# # Testing

# %%
driver.get('https://scholar.google.com/scholar?hl=en&as_sdt=0%2C5&q=milk+drought&oq=')
# assert "Google" in driver.title
# element = driver.find_element(By.NAME, "q")
# element.clear() # clear any pre-populated text in the input field (eg 'search')
# element.send_keys("pycon")
# element.send_keys(Keys.RETURN)
# assert "No results found." not in driver.page_source
# driver.close()

# %%
driver.page_source
# Out:
# '<html class="gs_el_ta gs_el_sm"><head><title>milk drought - Google Scholar</title><meta http-equiv="Content-Type" content="text/html;charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="referrer" content="origin-when-cross-origin"><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=2"><meta name="format-detection" content="telephone=no"><link rel="shortcut icon" href="/favicon.ico"><style>html,body,form,table,div,h1,h2,h3,h4,h5,h6,img,ol,ul,li,button{margin:0;padding:0;border:0;}table{border-collapse:collapse;border-width:0;empty-cells:show;}html,body{height:100%}#gs_top{position:relative;box-sizing:border-box;min-height:100%;min-width:964px;-webkit-tap-highlight-color:rgba(0,0,0,0);}#gs_top>*:not(#x){-webkit-tap-highlight-color:rgba(204,204,204,.5);}.gs_el_ph #gs_top,.gs_el_ta #gs_top{min-width:320px;}#gs_top.gs_nscl{position:fixed;width:100%;}body,td,input,button{font-size:13px;font-family:Arial,sans-serif;line
# ...

# %%
testTitle = driver.find_element(By.XPATH, '//*[@id="qc1Sr-ZfzJ8J"]/b[2]')

# for element in driver.find_elements(By.XPATH, '//div[@class="quote"]'):
# #   print('___\n___',element.text)

# %%
print(testTitle.text)
# Out:
# milk

# %%
testTitle.text
# Out:
# 'milk'

# %%
testClass = driver.find_element(By.XPATH, '//*[@id="gs_res_ccl_mid"]/div[1]/div/h3')

# %%
testClass.text
# Out:
# 'Effect of drought condition on the quality of camel milk'

# %%
parentClass = driver.find_element(By.XPATH, '//*[@id="gs_res_ccl_mid"]/div[1]/div')

# %%
parentClass.text
# Out:
# 'Effect of drought condition on the quality of camel milk\nR Yagil, Z Etzion - Journal of Dairy Research, 1980 - cambridge.org\n… increased water percentages in the milk when compared with milk of hydrated camels. The\n… in milk increased while Ca and Mg concentration declined. The urea concentration of the milk …\nSave Cite Cited by 247 Related articles All 7 versions'

# %%
multiClass = driver.find_element(By.XPATH, '//*[@id="gs_res_ccl"]')

# %%
print(multiClass.text)
# Out:
# Effect of drought condition on the quality of camel milk
# R Yagil, Z Etzion - Journal of Dairy Research, 1980 - cambridge.org
# … increased water percentages in the milk when compared with milk of hydrated camels. The
# … in milk increased while Ca and Mg concentration declined. The urea concentration of the milk …
# Save Cite Cited by 247 Related articles All 7 versions
# Milk yield of camels (Camelus dromedarius) in drought areas.
# R Yagil, Z Etzion - Comparative Biochemistry and Physiology, 1980 - cabdirect.org
# The milk yields of 3 camels were determined by measurements of tritium dilution in their calves,
# whose only source of water was the dams' milk. During periods of water restriction, dams …
# Save Cite Cited by 81 Related articles All 6 versions
# Accumulation of silymarin in milk thistle seeds under drought stress
# R Keshavarz Afshar, MR Chaichi, M Ansari Jovini… - Planta, 2015 - Springer
# ...

# %%
parentElements = driver.find_elements(By.XPATH, '//*[@id="gs_res_ccl_mid"]')

# Now you have a list of all elements matching the XPath expression
for element in parentElements:
    # You can access and manipulate each element as needed
    print(element.text)
# Out:
# Effect of drought condition on the quality of camel milk
# R Yagil, Z Etzion - Journal of Dairy Research, 1980 - cambridge.org
# … increased water percentages in the milk when compared with milk of hydrated camels. The
# … in milk increased while Ca and Mg concentration declined. The urea concentration of the milk …
# Save Cite Cited by 247 Related articles All 7 versions
# Milk yield of camels (Camelus dromedarius) in drought areas.
# R Yagil, Z Etzion - Comparative Biochemistry and Physiology, 1980 - cabdirect.org
# The milk yields of 3 camels were determined by measurements of tritium dilution in their calves,
# whose only source of water was the dams' milk. During periods of water restriction, dams …
# Save Cite Cited by 81 Related articles All 6 versions
# Accumulation of silymarin in milk thistle seeds under drought stress
# R Keshavarz Afshar, MR Chaichi, M Ansari Jovini… - Planta, 2015 - Springer
# ...

# %%
import csv

# %%
# # # Create and open a CSV file for writing
# with open('multiclass.csv', 'w', newline='', encoding='utf-8') as csvfile:
#     csv_writer = csv.writer(csvfile)

#     # Write headers (if applicable)
#     # csv_writer.writerow(['Header1', 'Header2', ...])

#     # Write the data from the web page to the CSV file
#     for element in parentElements:
#         data = element.text
#         csv_writer.writerow([data])
